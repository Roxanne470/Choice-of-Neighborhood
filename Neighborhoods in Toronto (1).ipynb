# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
url
# Out:
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
rows = soup.find_all('tr')

# %%
import re
list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '', str_cells))
    list_rows.append(clean2)

# %%
df = pd.DataFrame(list_rows)

# %%
df.head()
# Out:
#                                            0
# 0                                         []
# 1    [M1A\n, Not assigned\n, Not assigned\n]
# 2    [M2A\n, Not assigned\n, Not assigned\n]
# 3         [M3A\n, North York\n, Parkwoods\n]
# 4  [M4A\n, North York\n, Victoria Village\n]

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(5)
# Out:
#        0                1                     2     3     4     5     6   \
# 0      []             None                  None  None  None  None  None
# 1  [M1A\n   Not assigned\n       Not assigned\n]  None  None  None  None
# 2  [M2A\n   Not assigned\n       Not assigned\n]  None  None  None  None
# 3  [M3A\n     North York\n          Parkwoods\n]  None  None  None  None
# 4  [M4A\n     North York\n   Victoria Village\n]  None  None  None  None
#
#      7     8     9   ...     21    22    23    24    25    26    27    28  \
# 0  None  None  None  ...   None  None  None  None  None  None  None  None
# 1  None  None  None  ...   None  None  None  None  None  None  None  None
# 2  None  None  None  ...   None  None  None  None  None  None  None  None
# 3  None  None  None  ...   None  None  None  None  None  None  None  None
# 4  None  None  None  ...   None  None  None  None  None  None  None  None
#
#      29    30
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 31 columns]

# %%
df1[0] = df1[0].str.strip('[')
df1.head()
# Out:
#       0                1                     2     3     4     5     6     7   \
# 0      ]             None                  None  None  None  None  None  None
# 1  M1A\n   Not assigned\n       Not assigned\n]  None  None  None  None  None
# 2  M2A\n   Not assigned\n       Not assigned\n]  None  None  None  None  None
# 3  M3A\n     North York\n          Parkwoods\n]  None  None  None  None  None
# 4  M4A\n     North York\n   Victoria Village\n]  None  None  None  None  None
#
#      8     9   ...     21    22    23    24    25    26    27    28    29  \
# 0  None  None  ...   None  None  None  None  None  None  None  None  None
# 1  None  None  ...   None  None  None  None  None  None  None  None  None
# 2  None  None  ...   None  None  None  None  None  None  None  None  None
# 3  None  None  ...   None  None  None  None  None  None  None  None  None
# 4  None  None  ...   None  None  None  None  None  None  None  None  None
#
#      30
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
# [5 rows x 31 columns]

# %%
range(df1.shape[1])
# Out:
# range(0, 31)

# %%
for i in range(df1.shape[1]):
    df1[i] = df1[i].str.strip(']')
    df1[i] = df1[i].str.strip('\n')

# %%
df1.rename(columns = {0: 'PostalCode', 1: 'Borough'}, inplace = True)
df1.head()
# Out:
#   PostalCode        Borough                  2     3     4     5     6     7  \
# 0                      None               None  None  None  None  None  None
# 1        M1A   Not assigned       Not assigned  None  None  None  None  None
# 2        M2A   Not assigned       Not assigned  None  None  None  None  None
# 3        M3A     North York          Parkwoods  None  None  None  None  None
# 4        M4A     North York   Victoria Village  None  None  None  None  None
#
#       8     9  ...     21    22    23    24    25    26    27    28    29  \
# 0  None  None  ...   None  None  None  None  None  None  None  None  None
# 1  None  None  ...   None  None  None  None  None  None  None  None  None
# 2  None  None  ...   None  None  None  None  None  None  None  None  None
# 3  None  None  ...   None  None  None  None  None  None  None  None  None
# 4  None  None  ...   None  None  None  None  None  None  None  None  None
#
#      30
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
# [5 rows x 31 columns]

# %%
df2 = df1[df1['Borough'] != ' Not assigned']

# %%
df2 = df2[1:]

# %%
df2.reset_index(drop = True, inplace = True)

# %%
df2['Neighborhood'] = df2[df2.columns[2:]].apply(lambda x: ','.join(x.dropna().astype(str)), axis = 1)
df2.head()
# Out:
#   PostalCode            Borough                  2  \
# 0        M3A         North York          Parkwoods
# 1        M4A         North York   Victoria Village
# 2        M5A   Downtown Toronto        Regent Park
# 3        M6A         North York     Lawrence Manor
# 4        M7A   Downtown Toronto       Queen's Park
#
#                                 3     4     5     6     7     8     9  \
# 0                            None  None  None  None  None  None  None
# 1                            None  None  None  None  None  None  None
# 2                    Harbourfront  None  None  None  None  None  None
# 3                Lawrence Heights  None  None  None  None  None  None
# 4   Ontario Provincial Government  None  None  None  None  None  None
#
#                        ...                         22    23    24    25    26  \
# 0                      ...                       None  None  None  None  None
# 1                      ...                       None  None  None  None  None
# 2                      ...                       None  None  None  None  None
# 3                      ...                       None  None  None  None  None
# 4                      ...                       None  None  None  None  None
#
#      27    28    29    30                                  Neighborhood
# 0  None  None  None  None                                     Parkwoods
# 1  None  None  None  None                              Victoria Village
# 2  None  None  None  None                     Regent Park, Harbourfront
# 3  None  None  None  None              Lawrence Manor, Lawrence Heights
# 4  None  None  None  None   Queen's Park, Ontario Provincial Government
#
# [5 rows x 32 columns]

# %%
data = df2[['PostalCode','Borough','Neighborhood']]
data.tail()
# Out:
#                                             PostalCode     Borough  \
# 102                                                M8Z   Etobicoke
# 103
# 104  NL\n\nNS\n\nPE\n\nNB\n\nQC\n\nON\n\nMB\n\nSK\n...          NL
# 105                                                 NL          NS
# 106                                                  A           B
#
#                                           Neighborhood
# 102   Mimico NW, The Queensway West, South of Bloor...
# 103
# 104   NS, PE, NB, QC, ON, MB, SK, AB, BC, NU/NT, YT...
# 105          PE, NB, QC, ON, MB, SK, AB, BC, NU/NT, YT
# 106     C, E, G, H, J, K, L, M, N, P, R, S, T, V, X, Y

# %% [markdown]
# ### When the tail of the "data" dataframe was displayed, the last three rows are unwanted data as they have PostalCodes that don't seem to make sense.

# %%
data = data[0:103]
data.tail()
# Out:
#     PostalCode            Borough  \
# 98         M8X          Etobicoke
# 99         M4Y   Downtown Toronto
# 100        M7Y       East Toronto
# 101        M8Y          Etobicoke
# 102        M8Z          Etobicoke
#
#                                           Neighborhood
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100   Business reply mail Processing Centre, South ...
# 101   Old Mill South, King's Mill Park, Sunnylea, H...
# 102   Mimico NW, The Queensway West, South of Bloor...

# %%
data.shape[0]
# Out:
# 103

# %%
geodata = pd.read_csv("Geospatial_Coordinates.csv")

# %%
geodata.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geodf = pd.merge(data, geodata, left_on ='PostalCode', right_on = 'Postal Code')

# %%
geodf.drop('Postal Code', axis = 1, inplace = True)

# %%
geodf.head(10)
# Out:
#   PostalCode            Borough                                  Neighborhood  \
# 0        M3A         North York                                     Parkwoods
# 1        M4A         North York                              Victoria Village
# 2        M5A   Downtown Toronto                     Regent Park, Harbourfront
# 3        M6A         North York              Lawrence Manor, Lawrence Heights
# 4        M7A   Downtown Toronto   Queen's Park, Ontario Provincial Government
# 5        M9A          Etobicoke       Islington Avenue, Humber Valley Village
# 6        M1B        Scarborough                                Malvern, Rouge
# 7        M3B         North York                                     Don Mills
# 8        M4B          East York               Parkview Hill, Woodbine Gardens
# 9        M5B   Downtown Toronto                      Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937
